# %%
import numpy as np

# %%
marks = np.array([[85,90,88],[78,82,80],[92,95,94]])

# %%
marks
# Out:
# array([[85, 90, 88],
#        [78, 82, 80],
#        [92, 95, 94]])

# %%
np.mean(marks,axis=1)
# Out:
# array([87.66666667, 80.        , 93.66666667])

# %%
marks.max()
# Out:
# np.int64(95)

# %%
np.mean(marks,axis=0)
# Out:
# array([85.        , 89.        , 87.33333333])

# %%
np.argmax(np.mean(marks,axis=1))
# Out:
# np.int64(2)

# %%
np.sum(marks,axis=1)
# Out:
# array([263, 240, 281])

# %%
np.max(marks,axis=0)
# Out:
# array([92, 95, 94])
